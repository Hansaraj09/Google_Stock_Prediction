# %%
! pip install yfinance

# %%
import yfinance as yf
ticker = 'GOOG'

data = yf.download(ticker, start = '2004-08-19',end = '2024-11-03')

data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                         GOOG      GOOG      GOOG      GOOG      GOOG
# Date
# 2004-08-19 00:00:00+00:00  2.493011  2.499133  2.591785  2.390042  2.490664
# 2004-08-20 00:00:00+00:00  2.691030  2.697639  2.716817  2.503118  2.515820
# 2004-08-23 00:00:00+00:00  2.718112  2.724787  2.826406  2.716070  2.758411
# 2004-08-24 00:00:00+00:00  2.605561  2.611960  2.779581  2.579581  2.770615
# 2004-08-25 00:00:00+00:00  2.633636  2.640104  2.689918  2.587302  2.614201
#
# Price                         Volume
# Ticker                          GOOG
# Date
# 2004-08-19 00:00:00+00:00  897427216
# 2004-08-20 00:00:00+00:00  458857488
# 2004-08-23 00:00:00+00:00  366857939
# 2004-08-24 00:00:00+00:00  306396159
# 2004-08-25 00:00:00+00:00  184645512

# %%
data
# Out:
# Price                       Adj Close       Close        High         Low  \
# Ticker                           GOOG        GOOG        GOOG        GOOG
# Date
# 2004-08-19 00:00:00+00:00    2.493011    2.499133    2.591785    2.390042
# 2004-08-20 00:00:00+00:00    2.691030    2.697639    2.716817    2.503118
# 2004-08-23 00:00:00+00:00    2.718112    2.724787    2.826406    2.716070
# 2004-08-24 00:00:00+00:00    2.605561    2.611960    2.779581    2.579581
# 2004-08-25 00:00:00+00:00    2.633636    2.640104    2.689918    2.587302
# ...                               ...         ...         ...         ...
# 2024-10-28 00:00:00+00:00  168.339996  168.339996  170.606003  165.789993
# 2024-10-29 00:00:00+00:00  171.139999  171.139999  171.860001  168.660004
# 2024-10-30 00:00:00+00:00  176.139999  176.139999  183.789993  175.744995
# 2024-10-31 00:00:00+00:00  172.690002  172.690002  178.419998  172.559998
# 2024-11-01 00:00:00+00:00  172.649994  172.649994  173.820007  170.309998
#
# ...

# %%
data.to_csv('google_stock.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('google_stock.csv')

# %%
df
# Out:
#                            Date   Adj Close       Close        High  \
# 0     2004-08-19 00:00:00+00:00    2.493011    2.499133    2.591785
# 1     2004-08-20 00:00:00+00:00    2.691030    2.697639    2.716817
# 2     2004-08-23 00:00:00+00:00    2.718112    2.724787    2.826406
# 3     2004-08-24 00:00:00+00:00    2.605561    2.611960    2.779581
# 4     2004-08-25 00:00:00+00:00    2.633636    2.640104    2.689918
# ...                         ...         ...         ...         ...
# 5082  2024-10-28 00:00:00+00:00  168.339996  168.339996  170.606003
# 5083  2024-10-29 00:00:00+00:00  171.139999  171.139999  171.860001
# 5084  2024-10-30 00:00:00+00:00  176.139999  176.139999  183.789993
# 5085  2024-10-31 00:00:00+00:00  172.690002  172.690002  178.419998
# 5086  2024-11-01 00:00:00+00:00  172.649994  172.649994  173.820007
#
#              Low        Open     Volume
# 0       2.390042    2.490664  897427216
# 1       2.503118    2.515820  458857488
# ...

# %%
df['Date']
# Out:
# 0       2004-08-19 00:00:00+00:00
# 1       2004-08-20 00:00:00+00:00
# 2       2004-08-23 00:00:00+00:00
# 3       2004-08-24 00:00:00+00:00
# 4       2004-08-25 00:00:00+00:00
#                   ...
# 5082    2024-10-28 00:00:00+00:00
# 5083    2024-10-29 00:00:00+00:00
# 5084    2024-10-30 00:00:00+00:00
# 5085    2024-10-31 00:00:00+00:00
# 5086    2024-11-01 00:00:00+00:00
# Name: Date, Length: 5087, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'] = df['Date'].dt.date

# %%
df
# Out:
#             Date   Adj Close       Close        High         Low        Open  \
# 0     2004-08-19    2.493011    2.499133    2.591785    2.390042    2.490664
# 1     2004-08-20    2.691030    2.697639    2.716817    2.503118    2.515820
# 2     2004-08-23    2.718112    2.724787    2.826406    2.716070    2.758411
# 3     2004-08-24    2.605561    2.611960    2.779581    2.579581    2.770615
# 4     2004-08-25    2.633636    2.640104    2.689918    2.587302    2.614201
# ...          ...         ...         ...         ...         ...         ...
# 5082  2024-10-28  168.339996  168.339996  170.606003  165.789993  170.589996
# 5083  2024-10-29  171.139999  171.139999  171.860001  168.660004  169.384995
# 5084  2024-10-30  176.139999  176.139999  183.789993  175.744995  182.410004
# 5085  2024-10-31  172.690002  172.690002  178.419998  172.559998  174.720001
# 5086  2024-11-01  172.649994  172.649994  173.820007  170.309998  171.539993
#
#          Volume
# 0     897427216
# ...

# %%
df = df[['Date','Close']]

# %%
df
# Out:
#             Date       Close
# 0     2004-08-19    2.499133
# 1     2004-08-20    2.697639
# 2     2004-08-23    2.724787
# 3     2004-08-24    2.611960
# 4     2004-08-25    2.640104
# ...          ...         ...
# 5082  2024-10-28  168.339996
# 5083  2024-10-29  171.139999
# 5084  2024-10-30  176.139999
# 5085  2024-10-31  172.690002
# 5086  2024-11-01  172.649994
#
# [5087 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       2004-08-19
# 1       2004-08-20
# 2       2004-08-23
# 3       2004-08-24
# 4       2004-08-25
#            ...
# 5082    2024-10-28
# 5083    2024-10-29
# 5084    2024-10-30
# 5085    2024-10-31
# 5086    2024-11-01
# Name: Date, Length: 5087, dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Date']
# Out:
# <ipython-input-109-6e648d68c4ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']=pd.to_datetime(df['Date'])
# 0      2004-08-19
# 1      2004-08-20
# 2      2004-08-23
# 3      2004-08-24
# 4      2004-08-25
#           ...
# 5082   2024-10-28
# 5083   2024-10-29
# 5084   2024-10-30
# 5085   2024-10-31
# 5086   2024-11-01
# Name: Date, Length: 5087, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 2004-08-19    2.499133
# 2004-08-20    2.697639
# 2004-08-23    2.724787
# 2004-08-24    2.611960
# 2004-08-25    2.640104
# ...                ...
# 2024-10-28  168.339996
# 2024-10-29  171.139999
# 2024-10-30  176.139999
# 2024-10-31  172.690002
# 2024-11-01  172.649994
#
# [5087 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index,df['Close'])

# %%
# To convert the date into supervised leanrning mode having the target date and 3 days previous dates
import numpy as np
import datetime

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = pd.to_datetime(first_date_str)
  last_date  = pd.to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-08-24'
windowed_df = df_to_windowed_df(df,
                                '2023-08-24',
                                '2024-11-01',
                                n=3)
windowed_df

# we have 3 days before, 2 days before and 1 day before value which is fed into the model to get value of that particular date
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2023-08-24  128.929993  129.690002  133.210007  130.419998
# 1    2023-08-25  129.690002  133.210007  130.419998  130.690002
# 2    2023-08-28  133.210007  130.419998  130.690002  131.789993
# 3    2023-08-29  130.419998  130.690002  131.789993  135.490005
# 4    2023-08-30  130.690002  131.789993  135.490005  136.929993
# ..          ...         ...         ...         ...         ...
# 296  2024-10-28  164.479996  164.529999  166.990005  168.339996
# 297  2024-10-29  164.529999  166.990005  168.339996  171.139999
# 298  2024-10-30  166.990005  168.339996  171.139999  176.139999
# 299  2024-10-31  168.339996  171.139999  176.139999  172.690002
# 300  2024-11-01  171.139999  176.139999  172.690002  172.649994
#
# [301 rows x 5 columns]

# %%
# now we convert them into numpy array

def windowed_df_to_date_X_y(windowed_dataframe):

  df_as_np  =windowed_dataframe.to_numpy()
  dates = df_as_np[:,0]

  middle_matrix = df_as_np[:,1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1)) #Reshapes middle_matrix to 3D, specifically for an LSTM model, which expects 3D input: (samples, timesteps, features).

  y = df_as_np[:,-1]
  return dates, X.astype(np.float32), y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

# %%
dates.shape,X.shape,y.shape
# Out:
# ((301,), (301, 3, 1), (301,))

# %%
# Split our dateset
_80 = int(len(dates)* 0.8)
_90 = int(len(dates)*0.9)

dates_train,X_train,y_train = dates[:_80],X[:_80],y[:_80]
dates_val,X_val,y_val = dates[_80:_90],X[_80:_90],y[_80:_90]
dates_test,X_test,y_test = dates[_90:],X[_90:],y[_90:]

plt.plot(dates_train,y_train)
plt.plot(dates_val,y_val)
plt.plot(dates_test,y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              33 │
# ...

# %%
model.compile(loss = 'mse',
              optimizer =Adam(learning_rate=0.001),
              metrics =['mean_absolute_error'])


model.fit(X_train,y_train,validation_data =(X_val,y_val),epochs = 100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 23066.7500 - mean_absolute_error: 150.7985 - val_loss: 25713.5254 - val_mean_absolute_error: 160.2630
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22559.7324 - mean_absolute_error: 149.1504 - val_loss: 25404.9199 - val_mean_absolute_error: 159.2973
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22571.8633 - mean_absolute_error: 149.1548 - val_loss: 25043.0508 - val_mean_absolute_error: 158.1573
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21887.2793 - mean_absolute_error: 146.8698 - val_loss: 24616.5039 - val_mean_absolute_error: 156.8028
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21983.1465 - mean_absolute_error: 147.0740 - val_loss: 24013.1953 - val_mean_absolute_error: 154.8667
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21018.9629 - mean_absolute_error: 143.8638 - val_loss: 23064.3711 - val_mean_absolute_error: 151.7722
# Epoch 7/100
# ...

# %%
# Visualizing
# For Training
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train,train_predictions)
plt.plot(dates_train,y_train)
plt.legend(['Training Predicitons','Training Observations'])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
# For validation
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val,val_predictions)
plt.plot(dates_val,y_val)
plt.legend(['Validation Predicitons','Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# for testing
test_predictions = model.predict(X_test).flatten()
plt.plot(dates_test,test_predictions)
plt.plot(dates_test,y_test)
plt.legend(['test Predicitons','test Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
# all the three plots
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
# Now after Visualizing we found that when we take from dates August 24,2023 to November 1,2024 we found that the validation mean absolute error for the dataset is minimum and the validation and the test curves are more matching with each other for Observations and Predictions
# Now we consider training and testing for the above dataset

from copy import deepcopy
recursive_predictions = []

recursive_dates = np.concatenate([dates_val, dates_test])
for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction  =model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# ...

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
